# %% [markdown]
# https://github.com/choderalab/yank
# https://anaconda.org/omnia/yank
# http://getyank.org/latest/
#
# ```bash
# conda install -c omnia yank
# ```

# %% [markdown]
# Yank no tiene versión para python 3.7, sólo para 3.6. Esta es la razón por la cual academia está en python 3.6
